# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import joblib
import seaborn as sns
sns.set_palette(sns.color_palette("hls", 11))

# %matplotlib inline

# %%
data = joblib.load('./representations.joblib')

# %%
data.keys()
# Out:
# dict_keys(['/ssdrive/WinEarthPhotosByKeyword/Moon', '/ssdrive/WinEarthPhotosByKeyword/DockUndock', '/ssdrive/WinEarthPhotosByKeyword/Stars60Photos', '/ssdrive/WinEarthPhotosByKeyword/Volcano20Photos', '/ssdrive/WinEarthPhotosByKeyword/Cupola75Photos', '/ssdrive/WinEarthPhotosByKeyword/Movies3of36PhotosEach', '/ssdrive/WinEarthPhotosByKeyword/Aurora', '/ssdrive/WinEarthPhotosByKeyword/Night', '/ssdrive/WinEarthPhotosByKeyword/Structure', '/ssdrive/WinEarthPhotosByKeyword/Day', '/ssdrive/WinEarthPhotosByKeyword/SunriseSunset'])

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

X = []
labels = []
for label, key in enumerate(data):
    for _ in data[key][0]:
        labels.append(label)
    for x in data[key]:
        X.extend(x)

# %%
len(X)
# Out:
# 963

# %%
X[0].shape
# Out:
# (2048,)

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# %%
x, y = zip(*X_tsne)

# %%
cm = []
colors = sns.color_palette()
for label in labels:
    cm.append(colors[label])

# %%
plt.scatter(x,y,color=cm, marker='.')
